# %%
import pandas as pd

df = pd.read_excel ('extention_of_Z_Alizadeh_sani_dataset.xls')
print(df)
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current_Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ... Lymph Neut  PLT EF-TTE Region_RWMA     VHD       LAD  \
# 0            0   0  ...    39   52  261     50           0       N  Stenotic
# 1            0   0  ...    38   55  165     40           4       N  Stenotic
# 2            0   0  ...    38   60  230     40           2    mild  Stenotic
# 3            0   0  ...    18   72  742     55           0  Severe    Normal
# 4            0   0  ...    55   39  274     50           0  Severe    Normal
# ..         ...  ..  ...   ...  ...  ...    ...         ...     ...       ...
# 298          0   0  ...    34   58  251     45           0       N  Stenotic
# 299          0   0  ...    16   80  377     40           0    mild    Normal
# 300          0   1  ...    35   55  279     55           0       N    Normal
# 301          0   0  ...    48   40  208     55           0       N    Normal
# 302          0   0  ...    32   55  302     55           0       N  Stenotic
#
#           LCX       RCA    Cath
# 0      Normal  Stenotic     CAD
# 1    Stenotic    Normal     CAD
# 2      Normal    Normal     CAD
# 3      Normal    Normal  Normal
# 4      Normal    Normal  Normal
# ..        ...       ...     ...
# 298  Stenotic  Stenotic     CAD
# 299    Normal    Normal  Normal
# 300    Normal    Normal  Normal
# 301    Normal    Normal  Normal
# 302    Normal    Normal     CAD
#
# [303 rows x 59 columns]

# %%
Sex_dict={'Male':1,'Fmale':2}
Obesity_dict={'Y':1,'N':2}
LAD_dict={'Stenotic':1,'Normal':2}
VHD_dict={'N':1,'mild':2,'Moderate':3,'Severe':4}
Cath_dict={'CAD':1,'Normal':2}
BBB_dict={'N':1,'LBBB':2,'RBBB':3}
df['Sex_Ordinal']=df.Sex.map(Sex_dict)
df['Obesity_Ordinal']=df.Obesity.map(Obesity_dict)
df['CRF_Ordinal']=df.CRF.map(Obesity_dict)
df['CVA_Ordinal']=df.CVA.map(Obesity_dict)
df['Airway_disease_Ordinal']=df.Airway_disease.map(Obesity_dict)
df['Thyroid_Disease_Ordinal']=df.Thyroid_Disease.map(Obesity_dict)
df['CHF_Ordinal']=df.CHF.map(Obesity_dict)
df['DLP_Ordinal']=df.DLP.map(Obesity_dict)
df['Weak_Peripheral_Pulse_Ordinal']=df.Weak_Peripheral_Pulse.map(Obesity_dict)
df['Lung_rales_Ordinal']=df.Lung_rales.map(Obesity_dict)
df['Systolic_Murmur_Ordinal']=df.Systolic_Murmur.map(Obesity_dict)
df['Diastolic_Murmur_Ordinal']=df.Diastolic_Murmur.map(Obesity_dict)
df['Dyspnea_Ordinal']=df.Dyspnea.map(Obesity_dict)
df['Atypical_Ordinal']=df.Atypical.map(Obesity_dict)
df['Nonanginal_Ordinal']=df.Nonanginal.map(Obesity_dict)
df['Exertional_CP_Ordinal']=df.Exertional_CP.map(Obesity_dict)
df['LowTH_Ang_Ordinal']=df.LowTH_Ang.map(Obesity_dict)
df['LVH_Ordinal']=df.LVH.map(Obesity_dict)
df['Poor_R_Progression_Ordinal']=df.Poor_R_Progression.map(Obesity_dict)
df['BBB_Ordinal']=df.BBB.map(BBB_dict)
df['VHD_Ordinal']=df.VHD.map(VHD_dict)
df['LAD_Ordinal']=df.LAD.map(LAD_dict)
df['LCX_Ordinal']=df.LCX.map(LAD_dict)
df['RCA_Ordinal']=df.RCA.map(LAD_dict)
df['Cath_Ordinal']=df.Cath.map(Cath_dict)
print(df)
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current_Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ... Exertional_CP_Ordinal LowTH_Ang_Ordinal LVH_Ordinal  \
# 0            0   0  ...                     2                 2           2
# 1            0   0  ...                     2                 2           2
# 2            0   0  ...                     2                 2           2
# 3            0   0  ...                     2                 2           2
# 4            0   0  ...                     2                 2           2
# ..         ...  ..  ...                   ...               ...         ...
# 298          0   0  ...                     2                 2           2
# 299          0   0  ...                     2                 2           2
# 300          0   1  ...                     2                 2           2
# 301          0   0  ...                     2                 2           2
# 302          0   0  ...                     2                 2           2
#
#     Poor_R_Progression_Ordinal BBB_Ordinal VHD_Ordinal LAD_Ordinal  \
# 0                            2           1           1           1
# 1                            2           1           1           1
# 2                            2           1           2           1
# 3                            2           1           4           2
# 4                            2           1           4           2
# ..                         ...         ...         ...         ...
# 298                          2           1           1           1
# 299                          2           2           2           2
# 300                          2           3           1           2
# 301                          2           1           1           2
# 302                          2           1           1           1
#
#      LCX_Ordinal  RCA_Ordinal  Cath_Ordinal
# 0              2            1             1
# 1              1            2             1
# 2              2            2             1
# 3              2            2             2
# 4              2            2             2
# ..           ...          ...           ...
# 298            1            1             1
# 299            2            2             2
# 300            2            2             2
# 301            2            2             2
# 302            2            2             1
#
# [303 rows x 84 columns]

# %%
df=df.drop(['Sex', 'Obesity', 'CRF', 'CVA', 'Airway_disease', 'Thyroid_Disease', 'CHF', 'DLP', 'Weak_Peripheral_Pulse', 'Lung_rales', 'Systolic_Murmur', 'Diastolic_Murmur', 'Dyspnea', 'Atypical', 'Nonanginal', 'Exertional_CP', 'LowTH_Ang', 'LVH', 'Poor_R_Progression', 'BBB', 'VHD', 'LAD', 'LCX', 'RCA', 'Cath'], axis = 1)
print(df)
# Out:
#      Age  Weight  Length        BMI  DM  HTN  Current_Smoker  EX-Smoker  FH  \
# 0     53      90     175  29.387755   0    1               1          0   0
# 1     67      70     157  28.398718   0    1               0          0   0
# 2     54      54     164  20.077335   0    0               1          0   0
# 3     66      67     158  26.838648   0    1               0          0   0
# 4     50      87     153  37.165193   0    1               0          0   0
# ..   ...     ...     ...        ...  ..  ...             ...        ...  ..
# 298   58      84     168  29.761905   0    0               0          0   0
# 299   55      64     152  27.700831   0    0               0          0   0
# 300   48      77     160  30.078125   0    1               0          0   1
# 301   57      90     159  35.599858   1    0               0          0   0
# 302   56      85     170  29.411765   0    1               1          0   0
#
#       BP  ...  Exertional_CP_Ordinal  LowTH_Ang_Ordinal  LVH_Ordinal  \
# 0    110  ...                      2                  2            2
# 1    140  ...                      2                  2            2
# 2    100  ...                      2                  2            2
# 3    100  ...                      2                  2            2
# 4    110  ...                      2                  2            2
# ..   ...  ...                    ...                ...          ...
# 298  100  ...                      2                  2            2
# 299  100  ...                      2                  2            2
# 300  130  ...                      2                  2            2
# 301  100  ...                      2                  2            2
# 302  120  ...                      2                  2            2
#
#      Poor_R_Progression_Ordinal  BBB_Ordinal  VHD_Ordinal  LAD_Ordinal  \
# 0                             2            1            1            1
# 1                             2            1            1            1
# 2                             2            1            2            1
# 3                             2            1            4            2
# 4                             2            1            4            2
# ..                          ...          ...          ...          ...
# 298                           2            1            1            1
# 299                           2            2            2            2
# 300                           2            3            1            2
# 301                           2            1            1            2
# 302                           2            1            1            1
#
#      LCX_Ordinal  RCA_Ordinal  Cath_Ordinal
# 0              2            1             1
# 1              1            2             1
# 2              2            2             1
# 3              2            2             2
# 4              2            2             2
# ..           ...          ...           ...
# 298            1            1             1
# 299            2            2             2
# 300            2            2             2
# 301            2            2             2
# 302            2            2             1
#
# [303 rows x 59 columns]

# %%
X = df.drop('Cath_Ordinal',axis = 1)
y =df.iloc[:,-1].copy()
print(y)
print(X)
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      2
#       ..
# 298    1
# 299    2
# 300    2
# 301    2
# 302    1
# Name: Cath_Ordinal, Length: 303, dtype: int64
#      Age  Weight  Length        BMI  DM  HTN  Current_Smoker  EX-Smoker  FH  \
# 0     53      90     175  29.387755   0    1               1          0   0
# 1     67      70     157  28.398718   0    1               0          0   0
# 2     54      54     164  20.077335   0    0               1          0   0
# 3     66      67     158  26.838648   0    1               0          0   0
# 4     50      87     153  37.165193   0    1               0          0   0
# ..   ...     ...     ...        ...  ..  ...             ...        ...  ..
# 298   58      84     168  29.761905   0    0               0          0   0
# 299   55      64     152  27.700831   0    0               0          0   0
# 300   48      77     160  30.078125   0    1               0          0   1
# 301   57      90     159  35.599858   1    0               0          0   0
# 302   56      85     170  29.411765   0    1               1          0   0
#
#       BP  ...  Nonanginal_Ordinal  Exertional_CP_Ordinal  LowTH_Ang_Ordinal  \
# 0    110  ...                   2                      2                  2
# 1    140  ...                   2                      2                  2
# 2    100  ...                   2                      2                  2
# 3    100  ...                   1                      2                  2
# 4    110  ...                   2                      2                  2
# ..   ...  ...                 ...                    ...                ...
# 298  100  ...                   2                      2                  2
# 299  100  ...                   2                      2                  2
# 300  130  ...                   1                      2                  2
# 301  100  ...                   2                      2                  2
# 302  120  ...                   2                      2                  2
#
#      LVH_Ordinal  Poor_R_Progression_Ordinal  BBB_Ordinal  VHD_Ordinal  \
# 0              2                           2            1            1
# 1              2                           2            1            1
# 2              2                           2            1            2
# 3              2                           2            1            4
# 4              2                           2            1            4
# ..           ...                         ...          ...          ...
# 298            2                           2            1            1
# 299            2                           2            2            2
# 300            2                           2            3            1
# 301            2                           2            1            1
# 302            2                           2            1            1
#
#      LAD_Ordinal  LCX_Ordinal  RCA_Ordinal
# 0              1            2            1
# 1              1            1            2
# 2              1            2            2
# 3              2            2            2
# 4              2            2            2
# ..           ...          ...          ...
# 298            1            1            1
# 299            2            2            2
# 300            2            2            2
# 301            2            2            2
# 302            1            2            2
#
# [303 rows x 58 columns]

# %%
selected_features=['LAD_Ordinal','RCA_Ordinal','Typical_Chest_Pain','LCX_Ordinal','Region_RWMA','Atypical_Ordinal','Nonanginal_Ordinal','HTN','Age','DM','BP','FBS','HDL','LDL','BMI','St_Depression','BUN','Lymph','TG','Neut']

# %%
refinedX=X.filter(selected_features, axis=1)

# %%
print(refinedX,y)
# Out:
#      LAD_Ordinal  RCA_Ordinal  Typical_Chest_Pain  LCX_Ordinal  Region_RWMA  \
# 0              1            1                   0            2            0
# 1              1            2                   1            1            4
# 2              1            2                   1            2            2
# 3              2            2                   0            2            0
# 4              2            2                   0            2            0
# ..           ...          ...                 ...          ...          ...
# 298            1            1                   1            1            0
# 299            2            2                   0            2            0
# 300            2            2                   0            2            0
# 301            2            2                   0            2            0
# 302            1            2                   1            2            0
#
#      Atypical_Ordinal  Nonanginal_Ordinal  HTN  Age  DM   BP  FBS   HDL  LDL  \
# 0                   2                   2    1   53   0  110   90  30.0  155
# 1                   2                   2    1   67   0  140   80  36.0  121
# 2                   2                   2    0   54   0  100   85  45.0   70
# 3                   2                   1    1   66   0  100   78  27.0   55
# 4                   2                   2    1   50   0  110  104  50.0  110
# ..                ...                 ...  ...  ...  ..  ...  ...   ...  ...
# 298                 2                   2    0   58   0  100   92  44.0  115
# 299                 1                   2    0   55   0  100   86  23.0   40
# 300                 2                   1    1   48   0  130   83  42.0  112
# 301                 1                   2    0   57   1  100   96  49.0  130
# 302                 2                   2    1   56   0  120   78  34.0  124
#
#            BMI  St_Depression  BUN  Lymph   TG  Neut
# 0    29.387755              1    8     39  250    52
# 1    28.398718              1   30     38  309    55
# 2    20.077335              0   17     38  103    60
# 3    26.838648              1   30     18   63    72
# 4    37.165193              0   16     55  170    39
# ..         ...            ...  ...    ...  ...   ...
# 298  29.761905              0   13     34  112    58
# 299  27.700831              0   23     16  111    80
# 300  30.078125              0   13     35   93    55
# 301  35.599858              0   14     48  116    40
# 302  29.411765              0   16     32  139    55
#
# [303 rows x 20 columns] 0      1
# 1      1
# 2      1
# 3      2
# 4      2
#       ..
# 298    1
# 299    2
# 300    2
# 301    2
# 302    1
# Name: Cath_Ordinal, Length: 303, dtype: int64

# %%
import numpy as np
# Get some classifiers to evaluate
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import SVC
seed = 1075
np.random.seed(seed)
# Create classifiers
rf = RandomForestClassifier()
et = ExtraTreesClassifier()
knn = KNeighborsClassifier()
svc = SVC()
rg = RidgeClassifier()
clf_array = [rf, et, knn, svc, rg]
for clf in clf_array:
    vanilla_scores = cross_val_score(clf, refinedX, y, cv=10, n_jobs=-1)
    bagging_clf = BaggingClassifier(clf, 
       max_samples=0.4, max_features=10, random_state=seed)
    bagging_scores = cross_val_score(bagging_clf, refinedX, y, cv=10, 
       n_jobs=-1)
    print("Mean of: {1:.3f}, std: (+/-) {2:.3f} [{0}]".format(clf.__class__.__name__,vanilla_scores.mean(), vanilla_scores.std()))
    print("Mean of: {1:.3f}, std: (+/-) {2:.3f} [Bagging {0}]\n".format(clf.__class__.__name__, bagging_scores.mean(), bagging_scores.std()))
# Out:
# Mean of: 0.993, std: (+/-) 0.013 [RandomForestClassifier]
# Mean of: 0.950, std: (+/-) 0.040 [Bagging RandomForestClassifier]
#
# Mean of: 0.994, std: (+/-) 0.013 [ExtraTreesClassifier]
# Mean of: 0.960, std: (+/-) 0.042 [Bagging ExtraTreesClassifier]
#
# Mean of: 0.713, std: (+/-) 0.046 [KNeighborsClassifier]
# Mean of: 0.723, std: (+/-) 0.031 [Bagging KNeighborsClassifier]
#
# Mean of: 0.713, std: (+/-) 0.014 [SVC]
# Mean of: 0.713, std: (+/-) 0.014 [Bagging SVC]
#
# Mean of: 0.944, std: (+/-) 0.029 [RidgeClassifier]
# Mean of: 0.937, std: (+/-) 0.048 [Bagging RidgeClassifier]

# %%
# Example of hard voting 
from sklearn.ensemble import VotingClassifier
clf = [rf, et, knn, svc, rg]
eclf = VotingClassifier(estimators=[('Random Forests', rf), ('Extra Trees', et), ('KNeighbors', knn), ('SVC', svc), ('Ridge Classifier', rg)], voting='hard')
for clf, label in zip([rf, et, knn, svc, rg, eclf], ['Random Forest', 'Extra Trees', 'KNeighbors', 'SVC', 'Ridge Classifier', 'Ensemble']):
    scores = cross_val_score(clf, refinedX, y, cv=10, scoring='accuracy')
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.99 (+/- 0.02) [Random Forest]
# Accuracy: 1.00 (+/- 0.01) [Extra Trees]
# Accuracy: 0.71 (+/- 0.05) [KNeighbors]
# Accuracy: 0.71 (+/- 0.01) [SVC]
# Accuracy: 0.94 (+/- 0.03) [Ridge Classifier]
# Accuracy: 0.99 (+/- 0.01) [Ensemble]

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from mlxtend.classifier import EnsembleVoteClassifier
ada_boost = AdaBoostClassifier()
grad_boost = GradientBoostingClassifier()
xgb_boost = XGBClassifier()
boost_array = [ada_boost, grad_boost, xgb_boost]
eclf = EnsembleVoteClassifier(clfs=[ada_boost, grad_boost, xgb_boost], voting='hard')
labels = ['Ada Boost', 'Grad Boost', 'XG Boost', 'Ensemble']
for clf, label in zip([ada_boost, grad_boost, xgb_boost, eclf], labels):
    scores = cross_val_score(clf, X, y, cv=10, scoring='accuracy')
    print("Mean: {0:.3f}, std: (+/-) {1:.3f} [{2}]".format(scores.mean(), scores.std(), label))
# Out:
# Mean: 0.997, std: (+/-) 0.010 [Ada Boost]
# Mean: 0.997, std: (+/-) 0.010 [Grad Boost]
# Mean: 0.997, std: (+/-) 0.010 [XG Boost]
# Mean: 0.997, std: (+/-) 0.010 [Ensemble]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(refinedX, y, train_size=0.90)
print(X_train.shape, X_test.shape,y_train.shape,y_test.shape)
# Out:
# (272, 20) (31, 20) (272,) (31,)

# %%
from mlens.ensemble import SuperLearner
from itertools import combinations
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
names = ['Random Forest', 'Extra Trees', 'KNeighbors', 'SVC', 'Ridge Classifier']
def zip_stacked_classifiers(*args):
    to_zip = []
    for arg in args:
        combined_items = sum([list(map(list, combinations(arg, i))) for i in range(len(arg) + 1)], [])
        combined_items = filter(lambda x: len(x) > 0, combined_items)
        to_zip.append(combined_items)
    
    return zip(to_zip[0], to_zip[1])
stacked_clf_list = zip_stacked_classifiers(clf_array, names)
best_combination = [0.00, ""]
for clf in stacked_clf_list:
    ensemble = SuperLearner(scorer = accuracy_score,random_state = seed,folds = 10)
    ensemble.add(clf[0])
    ensemble.add_meta(lr)
    ensemble.fit(X_train, y_train)
    preds = ensemble.predict(X_test)
    accuracy = accuracy_score(preds, y_test)
   
    if accuracy > best_combination[0]:
        best_combination[0] = accuracy
        best_combination[1] = clf[1]
    print("Accuracy score: {:.3f} {}".format(accuracy, clf[1]))
print("\nBest stacking model is {} with accuracy of: {:.3f}".format(best_combination[1], best_combination[0]))
# Out:
# Accuracy score: 1.000 ['Random Forest']
# Accuracy score: 1.000 ['Extra Trees']
# Accuracy score: 0.645 ['KNeighbors']
# Accuracy score: 0.645 ['SVC']
# Accuracy score: 0.968 ['Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees']
# Accuracy score: 1.000 ['Random Forest', 'KNeighbors']
# Accuracy score: 1.000 ['Random Forest', 'SVC']
# Accuracy score: 1.000 ['Random Forest', 'Ridge Classifier']
# Accuracy score: 1.000 ['Extra Trees', 'KNeighbors']
# Accuracy score: 1.000 ['Extra Trees', 'SVC']
# Accuracy score: 1.000 ['Extra Trees', 'Ridge Classifier']
# Accuracy score: 0.645 ['KNeighbors', 'SVC']
# Accuracy score: 0.968 ['KNeighbors', 'Ridge Classifier']
# Accuracy score: 0.968 ['SVC', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'KNeighbors']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'SVC']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'KNeighbors', 'SVC']
# Accuracy score: 1.000 ['Random Forest', 'KNeighbors', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'SVC', 'Ridge Classifier']
# Accuracy score: 1.000 ['Extra Trees', 'KNeighbors', 'SVC']
# Accuracy score: 1.000 ['Extra Trees', 'KNeighbors', 'Ridge Classifier']
# Accuracy score: 1.000 ['Extra Trees', 'SVC', 'Ridge Classifier']
# Accuracy score: 0.968 ['KNeighbors', 'SVC', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'KNeighbors', 'SVC']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'KNeighbors', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'SVC', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'KNeighbors', 'SVC', 'Ridge Classifier']
# Accuracy score: 1.000 ['Extra Trees', 'KNeighbors', 'SVC', 'Ridge Classifier']
# Accuracy score: 1.000 ['Random Forest', 'Extra Trees', 'KNeighbors', 'SVC', 'Ridge Classifier']
#
# Best stacking model is ['Random Forest'] with accuracy of: 1.000
